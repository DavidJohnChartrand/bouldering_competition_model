# %%
# Import Dependencies
import os
import pandas as pd
import numpy as np
import time
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import func

# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
db_path = "sqlite:///climbing.sqlite"

engine = create_engine(db_path, echo=False)

url = "https://raw.githubusercontent.com/DavidJohnChartrand/bouldering_competition_model/main/resources/merged_df.csv"
climbing_df = pd.read_csv("https://raw.githubusercontent.com/DavidJohnChartrand/bouldering_competition_model/main/resources/merged_df.csv")
climbing_df

# %%
climbing_table = "climbing_table"
climbing_df.to_sql(climbing_table, engine, if_exists='replace', index=False)
